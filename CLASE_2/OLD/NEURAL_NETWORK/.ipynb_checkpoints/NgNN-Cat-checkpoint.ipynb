# %% [markdown]
# #### Se implimentó una red neuronal artificial entrenada para clasificar imagenes. La clasificacion de imagenes esta basada en sí estas contienen o no a un gato.  Se usa aprendizaje supervisado.
#
#
# #### Se importan los modulos que se van a usar:

# %%
import time
import numpy as np
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
from dnn_app_utils_v3 import *

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

np.random.seed(1)

# %% [markdown]
# #### La funcion load_dataset prepara y carga los datos.
#
# #### Hay dos tipos de datos (dependientes entre sí):
#
#      Un conjunto de imagenes que pueden contener gatos o no
#      La etiqueta asociada a cada imagen: 0 si no hay un gato en la imagen y 1 si hay un gato en la imagen.
#
# #### Un conjunto de datos de la forma (imagen, etiqueta) se utiliza para entrenar a la red (prefijo 'train') y otro conjunto de datos de la misma forma se usa para probar a la red entrenada (prefijo 'test').

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = load_data()


# train_set_x_orig ----> conjunto de imagenes de entrenamiento

# train_set_y ----> conjunto de etiquetas para las imagenes de entrenamiento

# test_set_x_orig ----> conjunto de imagenes de prueba

# test_set_y ----> conjunto de etiquetas para las imagenes de prueba


# Each line of your train_set_x_orig and test_set_x_orig is an array representing an image.

X = train_x_orig[:100]
Y = train_y.T
Y = Y[:100]
Y = Y.T
Y.shape
# Out:
# (1, 100)

# %% [markdown]
# ####  Se puede acceder a las imagenes de entrenamiento y de prueba, así como a sus respectivas etiquetas:

# %%
# Example of a picture
index = 88
plt.imshow(train_x_orig[index])
print ("y = " + str(train_y[0,index]) + ". It's a " + classes[train_y[0,index]].decode("utf-8") +  " picture.")
# Out:
# y = 1. It's a cat picture.

# %%
# Explore your dataset 
m_train = train_x_orig.shape[0]
num_px = train_x_orig.shape[1]
m_test = test_x_orig.shape[0]

print ("Number of training examples: " + str(m_train))
print ("Number of testing examples: " + str(m_test))
print ("Each image is of size: (" + str(num_px) + ", " + str(num_px) + ", 3)")
print ("train_x_orig shape: " + str(train_x_orig.shape))
print ("train_y shape: " + str(train_y.shape))
print ("test_x_orig shape: " + str(test_x_orig.shape))
print ("test_y shape: " + str(test_y.shape))
print ("y: " + str(Y.shape))
# Out:
# Number of training examples: 209
# Number of testing examples: 50
# Each image is of size: (64, 64, 3)
# train_x_orig shape: (209, 64, 64, 3)
# train_y shape: (1, 209)
# test_x_orig shape: (50, 64, 64, 3)
# test_y shape: (1, 50)
# y: (1, 100)

# %% [markdown]
# #### Las imagenes no son la entrada directa a la red, estas se tienen que vectorizar y normalizar.
#
#
# <img src="ima.png" style="width:550px;height:300px;">

# %%
# Reshape the training and test examples 
train_x_flatten = train_x_orig.reshape(train_x_orig.shape[0], -1).T   # The "-1" makes reshape flatten the remaining dimensions
test_x_flatten = test_x_orig.reshape(test_x_orig.shape[0], -1).T
X = X.reshape(X.shape[0], -1).T

# Standardize data to have feature values between 0 and 1.
train_x = train_x_flatten/255.
test_x = test_x_flatten/255.
X = X/255.
print ("train_x's shape: " + str(train_x.shape))
print ("test_x's shape: " + str(test_x.shape))
#print ("x's shape: " + str(X.shape))
# Out:
# train_x's shape: (12288, 209)
# test_x's shape: (12288, 50)
# x's shape: (12288, 100)

# %% [markdown]
# #### Se crea el modelo de la red neuronal:
#
#
# <img src="nlayer.png" style="width:750px;height:500px;">

# %%
def L_layer_model(X, Y, layers_dims, learning_rate = 0.0075, num_iterations = 3000, print_cost=False):#lr was 0.009
    """
    Implements a L-layer neural network: [LINEAR->RELU]*(L-1)->LINEAR->SIGMOID.
    
    Arguments:
    X -- data, numpy array of shape (number of examples, num_px * num_px * 3)
    Y -- true "label" vector (containing 0 if cat, 1 if non-cat), of shape (1, number of examples)
    layers_dims -- list containing the input size and each layer size, of length (number of layers + 1).
    learning_rate -- learning rate of the gradient descent update rule
    num_iterations -- number of iterations of the optimization loop
    print_cost -- if True, it prints the cost every 100 steps
    
    Returns:
    parameters -- parameters learnt by the model. They can then be used to predict.
    """
    tic = time.process_time()

    np.random.seed(1)
    costs = []                         # keep track of cost
    
    # Parameters initialization. (≈ 1 line of code)
    ### START CODE HERE ###
    parameters = initialize_parameters_deep(layers_dims)
    ### END CODE HERE ###
    
    # Loop (gradient descent)
    for i in range(0, num_iterations):

        # Forward propagation: [LINEAR -> RELU]*(L-1) -> LINEAR -> SIGMOID.
        ### START CODE HERE ### (≈ 1 line of code)
        AL, caches = L_model_forward(X, parameters)
        ### END CODE HERE ###
        
        # Compute cost.
        ### START CODE HERE ### (≈ 1 line of code)
        cost = compute_cost(AL, Y)
        ### END CODE HERE ###
    
        # Backward propagation.
        ### START CODE HERE ### (≈ 1 line of code)
        grads = L_model_backward(AL, Y, caches)
        ### END CODE HERE ###
 
        # Update parameters.
        ### START CODE HERE ### (≈ 1 line of code)
        parameters = update_parameters(parameters, grads, learning_rate)
        ### END CODE HERE ###
                
        # Print the cost every 100 training example
        if print_cost and i % 100 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))
        if print_cost and i % 100 == 0:
            costs.append(cost)
            
    pred_train = predict(train_x, train_y, parameters)
    toc = time.process_time()
    print ( "\n ----- Computation time = " + str(1000*(toc - tic)) + "ms")

    d = {}
            
    # plot the cost
    plt.plot(np.squeeze(costs))
    plt.ylabel('cost')
    plt.xlabel('iterations (per tens)')
    plt.title("Learning rate =" + str(learning_rate))
    plt.show()
    
    return parameters

# %% [markdown]
# #### La arquitectura de la red nos permite elegir el numero de capas intermedias así como el numero de unidades por capa, esta información se indica en el arreglo layers_dims.

# %%
layers_dims = [12288, 20, 7, 5, 3, 1]
parameters = L_layer_model(train_x, train_y, layers_dims, num_iterations = 2500, print_cost = True)
# Out:
# Cost after iteration 0: 0.709972
# Cost after iteration 100: 0.677225
# Cost after iteration 200: 0.665782
# Cost after iteration 300: 0.657526
# Cost after iteration 400: 0.650890
# Cost after iteration 500: 0.645032
# Cost after iteration 600: 0.637965
# Cost after iteration 700: 0.628129
# Cost after iteration 800: 0.608954
# Cost after iteration 900: 0.573956
# Cost after iteration 1000: 0.521117
# Cost after iteration 1100: 0.453512
# Cost after iteration 1200: 0.398820
# Cost after iteration 1300: 0.352213
# Cost after iteration 1400: 0.303050
# Cost after iteration 1500: 0.276419
# Cost after iteration 1600: 0.245984
# Cost after iteration 1700: 0.230691
# Cost after iteration 1800: 0.215385
# Cost after iteration 1900: 0.201817
# Cost after iteration 2000: 0.184110
# Cost after iteration 2100: 0.168439
# Cost after iteration 2200: 0.158414
# Cost after iteration 2300: 0.152595
# Cost after iteration 2400: 0.145581
# Accuracy: 0.9808612440191385
#
#  ----- Computation time = 111760.42498799996ms

# %%
pred_train = predict(train_x, train_y, parameters)
# Out:
# Accuracy: 0.9856459330143539

# %%
pred_test = predict(test_x, test_y, parameters)
# Out:
# Accuracy: 0.8

# %%
print_mislabeled_images(classes, test_x, test_y, pred_test)

# %%
my_image = "perro.jpg" # change this to the name of your image file 
my_label_y = [1] # the true class of your image (1 -> cat, 0 -> non-cat)
## END CODE HERE ##

fname =  my_image
image = np.array(ndimage.imread(fname, flatten=False))
my_image = scipy.misc.imresize(image, size=(num_px,num_px)).reshape((num_px*num_px*3,1))
my_image = my_image/255.
my_predicted_image = predict(my_image, my_label_y, parameters)

plt.imshow(image)
print ("y = " + str(np.squeeze(my_predicted_image)) + ", your L-layer model predicts a \"" + classes[int(np.squeeze(my_predicted_image)),].decode("utf-8") +  "\" picture.")
# Out:
# Accuracy: 0.0
# y = 0.0, your L-layer model predicts a "non-cat" picture.
# /home/bokhimi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
#   import sys
# /home/bokhimi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.

# %% [markdown]
# #### Los resultados de la red cambian si cambiamos sus parametros:

# %%
learning_rates = [0.01, 0.001, 0.0001, 0.005]

# lista con distintos valores para alpha

d = {}

# se crea un diccionario vacío

for i in learning_rates:
    
    # i = 0.01, 0.001, 0.0001
    
    print ("learning rate is: " + str(i))
    
    parameters = L_layer_model(train_x, train_y, layers_dims, i, num_iterations = 2500, print_cost = True)    
    
    print ('\n' + "-------------------------------------------------------" + '\n')
    
    # '\n' es un salto de línea
# Out:
# learning rate is: 0.01
# Cost after iteration 0: 0.709972
# Cost after iteration 100: 0.672904
# Cost after iteration 200: 0.659731
# Cost after iteration 300: 0.650718
# Cost after iteration 400: 0.642135
# Cost after iteration 500: 0.629593
# Cost after iteration 600: 0.603689
# Cost after iteration 700: 0.552247
# Cost after iteration 800: 0.476600
# Cost after iteration 900: 0.412127
# Cost after iteration 1000: 0.368836
# Cost after iteration 1100: 0.303740
# Cost after iteration 1200: 0.316237
# Cost after iteration 1300: 0.243841
# Cost after iteration 1400: 0.212253
# Cost after iteration 1500: 0.161758
# Cost after iteration 1600: 0.146638
# Cost after iteration 1700: 0.135152
# Cost after iteration 1800: 0.126617
# Cost after iteration 1900: 0.118674
# Cost after iteration 2000: 0.111817
# Cost after iteration 2100: 0.106992
# Cost after iteration 2200: 0.101338
# Cost after iteration 2300: 0.097336
# Cost after iteration 2400: 0.093363
# Accuracy: 0.9904306220095692
#
#  ----- Computation time = 117826.71992699988ms
# -------------------------------------------------------
#
# learning rate is: 0.001
# Cost after iteration 0: 0.709972
# Cost after iteration 100: 0.691237
# Cost after iteration 200: 0.688634
# Cost after iteration 300: 0.686233
# Cost after iteration 400: 0.683960
# Cost after iteration 500: 0.681815
# Cost after iteration 600: 0.679727
# Cost after iteration 700: 0.677767
# Cost after iteration 800: 0.675909
# Cost after iteration 900: 0.674136
# Cost after iteration 1000: 0.672448
# Cost after iteration 1100: 0.670846
# Cost after iteration 1200: 0.669308
# Cost after iteration 1300: 0.667794
# Cost after iteration 1400: 0.666341
# Cost after iteration 1500: 0.664931
# Cost after iteration 1600: 0.663601
# Cost after iteration 1700: 0.662344
# Cost after iteration 1800: 0.661100
# Cost after iteration 1900: 0.659912
# Cost after iteration 2000: 0.658764
# Cost after iteration 2100: 0.657652
# Cost after iteration 2200: 0.656574
# Cost after iteration 2300: 0.655482
# Cost after iteration 2400: 0.654416
# Accuracy: 0.6555023923444976
#
#  ----- Computation time = 113340.87915800001ms
# -------------------------------------------------------
#
# learning rate is: 0.0001
# Cost after iteration 0: 0.709972
# Cost after iteration 100: 0.699922
# Cost after iteration 200: 0.696423
# Cost after iteration 300: 0.694699
# Cost after iteration 400: 0.693669
# Cost after iteration 500: 0.693077
# Cost after iteration 600: 0.692636
# Cost after iteration 700: 0.692235
# Cost after iteration 800: 0.691875
# Cost after iteration 900: 0.691540
# Cost after iteration 1000: 0.691241
# Cost after iteration 1100: 0.690961
# Cost after iteration 1200: 0.690688
# Cost after iteration 1300: 0.690420
# Cost after iteration 1400: 0.690158
# Cost after iteration 1500: 0.689900
# Cost after iteration 1600: 0.689644
# Cost after iteration 1700: 0.689388
# Cost after iteration 1800: 0.689135
# Cost after iteration 1900: 0.688883
# Cost after iteration 2000: 0.688634
# Cost after iteration 2100: 0.688386
# Cost after iteration 2200: 0.688140
# Cost after iteration 2300: 0.687897
# Cost after iteration 2400: 0.687655
# Accuracy: 0.6507177033492824
#
#  ----- Computation time = 111263.97714400014ms
# -------------------------------------------------------
#
# learning rate is: 0.005
# Cost after iteration 0: 0.709972
# Cost after iteration 100: 0.681947
# Cost after iteration 200: 0.673036
# Cost after iteration 300: 0.665866
# Cost after iteration 400: 0.660197
# Cost after iteration 500: 0.655508
# Cost after iteration 600: 0.651218
# Cost after iteration 700: 0.647191
# Cost after iteration 800: 0.642985
# Cost after iteration 900: 0.638554
# Cost after iteration 1000: 0.633480
# Cost after iteration 1100: 0.626763
# Cost after iteration 1200: 0.617430
# Cost after iteration 1300: 0.605131
# Cost after iteration 1400: 0.587492
# Cost after iteration 1500: 0.561068
# Cost after iteration 1600: 0.524141
# Cost after iteration 1700: 0.482732
# Cost after iteration 1800: 0.439779
# Cost after iteration 1900: 0.404981
# Cost after iteration 2000: 0.370327
# Cost after iteration 2100: 0.347189
# Cost after iteration 2200: 0.316959
# Cost after iteration 2300: 0.297615
# Cost after iteration 2400: 0.273737
# Accuracy: 0.956937799043062
#
#  ----- Computation time = 110970.26256200002ms
# -------------------------------------------------------

# %%
layers_dims = [12288, 100, 1]


    
parameters = L_layer_model(train_x, train_y, layers_dims, print_cost = True)    
    
print ('\n' + "-------------------------------------------------------" + '\n')
# Out:
# Cost after iteration 0: 0.660545
# Cost after iteration 100: 0.490732
# Cost after iteration 200: 0.416712
# Cost after iteration 300: 0.347500
# Cost after iteration 400: 0.290583
# Cost after iteration 500: 0.232896
# Cost after iteration 600: 0.181621
# Cost after iteration 700: 0.137912
# Cost after iteration 800: 0.110687
# Cost after iteration 900: 0.088673
# Cost after iteration 1000: 0.071605
# Cost after iteration 1100: 0.060599
# Cost after iteration 1200: 0.052224
# Cost after iteration 1300: 0.045177
# Cost after iteration 1400: 0.039690
# Cost after iteration 1500: 0.035105
# Cost after iteration 1600: 0.031366
# Cost after iteration 1700: 0.028207
# Cost after iteration 1800: 0.025561
# Cost after iteration 1900: 0.023299
# Cost after iteration 2000: 0.021328
# Cost after iteration 2100: 0.019633
# Cost after iteration 2200: 0.018145
# Cost after iteration 2300: 0.016848
# Cost after iteration 2400: 0.015696
# Cost after iteration 2500: 0.014675
# Cost after iteration 2600: 0.013752
# Cost after iteration 2700: 0.012927
# Cost after iteration 2800: 0.012184
# Cost after iteration 2900: 0.011515
# Accuracy: 0.9999999999999998
#
#  ----- Computation time = 277112.68957099994ms
# -------------------------------------------------------

# %%
parameters = L_layer_model(X, Y, layers_dims, print_cost = True)
# Out:
# Cost after iteration 0: 0.690655
# Cost after iteration 100: 0.501482
# Cost after iteration 200: 0.437403
# Cost after iteration 300: 0.333624
# Cost after iteration 400: 0.101872
# Cost after iteration 500: 0.332149
# Cost after iteration 600: 0.140696
# Cost after iteration 700: 0.049329
# Cost after iteration 800: 0.022594
# Cost after iteration 900: 0.013251
# Cost after iteration 1000: 0.008713
# Cost after iteration 1100: 0.006256
# Cost after iteration 1200: 0.004848
# Cost after iteration 1300: 0.003915
# Cost after iteration 1400: 0.003254
# Cost after iteration 1500: 0.002765
# Cost after iteration 1600: 0.002389
# Cost after iteration 1700: 0.002094
# Cost after iteration 1800: 0.001856
# Cost after iteration 1900: 0.001660
# Cost after iteration 2000: 0.001497
# Cost after iteration 2100: 0.001359
# Cost after iteration 2200: 0.001242
# Cost after iteration 2300: 0.001141
# Cost after iteration 2400: 0.001053
# Cost after iteration 2500: 0.000977
# Cost after iteration 2600: 0.000909
# Cost after iteration 2700: 0.000849
# Cost after iteration 2800: 0.000795
# Cost after iteration 2900: 0.000747
# Accuracy: 0.7799043062200957
#
#  ----- Computation time = 84707.318967ms
